# %%
import pandas as pd

df_clean = pd.read_csv('../src/taxipred/data/processed/taxi_data_cleaned.csv')

# %%
import pandas as pd

df = pd.read_csv('../src/taxipred/data/processed/taxi_data_cleaned.csv')

df.head(10)

categorical_cols = ['Time_of_Day', 'Day_of_Week', 'Traffic_Conditions', 'Weather']

taxi_data = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

df.head(20)
# Out:
#     Trip_Distance_km Time_of_Day Day_of_Week  Passenger_Count  \
# 0              19.35     Morning     Weekday              3.0
# 1              36.87     Evening     Weekend              1.0
# 2               8.64   Afternoon     Weekend              2.0
# 3              41.79       Night     Weekend              3.0
# 4               9.91     Evening     Weekday              2.0
# 5               9.99       Night     Weekday              4.0
# 6              15.91     Morning     Weekday              4.0
# 7              26.71   Afternoon     Weekend              4.0
# 8              30.98   Afternoon     Weekend              1.0
# 9              18.95       Night     Weekday              1.0
# 10              3.28     Evening     Weekday              2.0
# 11             30.77     Morning     Weekday              1.0
# 12              9.36   Afternoon     Weekday              1.0
# 13             48.32     Morning     Weekday              2.0
# ...

# %%
taxi_data
# Out:
#      Trip_Distance_km  Passenger_Count  Base_Fare  Per_Km_Rate  \
# 0               19.35              3.0       3.56         0.80
# 1               36.87              1.0       2.70         1.21
# 2                8.64              2.0       2.55         1.71
# 3               41.79              3.0       4.60         1.77
# 4                9.91              2.0       2.32         1.26
# ..                ...              ...        ...          ...
# 543             40.17              3.0       3.81         0.66
# 544             14.34              1.0       3.23         1.01
# 545             18.69              3.0       4.90         1.79
# 546              5.49              4.0       2.39         0.62
# 547             47.56              1.0       2.67         0.82
#
#      Per_Minute_Rate  Trip_Duration_Minutes  Trip_Price  Time_of_Day_Evening  \
# 0               0.32                  53.82     36.2624                False
# ...

# %%
df.describe().T
# Out:
#                        count       mean        std     min       25%  \
# Trip_Distance_km       548.0  25.289380  14.307509  1.2700  12.87500
# Passenger_Count        548.0   2.540146   1.110130  1.0000   2.00000
# Base_Fare              548.0   3.513850   0.869567  2.0100   2.72750
# Per_Km_Rate            548.0   1.216679   0.428916  0.5000   0.84000
# Per_Minute_Rate        548.0   0.288850   0.115312  0.1000   0.19000
# Trip_Duration_Minutes  548.0  61.771442  32.291006  5.0100  36.33750
# Trip_Price             548.0  51.882792  24.236402  6.1269  33.30375
#
#                             50%        75%       max
# Trip_Distance_km       25.64000  37.757500   49.9900
# Passenger_Count         3.00000   4.000000    4.0000
# Base_Fare               3.54500   4.262500    5.0000
# Per_Km_Rate             1.19000   1.570000    2.0000
# Per_Minute_Rate         0.28000   0.390000    0.5000
# Trip_Duration_Minutes  61.41500  89.165000  119.8400
# ...

# %%
from sklearn.model_selection import train_test_split

x = taxi_data.drop('Trip_Price', axis=1) # Använd den nya DataFrame
y = taxi_data['Trip_Price']
x.head(15)
# Out:
#     Trip_Distance_km  Passenger_Count  Base_Fare  Per_Km_Rate  \
# 0              19.35              3.0       3.56         0.80
# 1              36.87              1.0       2.70         1.21
# 2               8.64              2.0       2.55         1.71
# 3              41.79              3.0       4.60         1.77
# 4               9.91              2.0       2.32         1.26
# 5               9.99              4.0       4.33         0.85
# 6              15.91              4.0       4.42         1.77
# 7              26.71              4.0       4.30         1.59
# 8              30.98              1.0       4.50         0.84
# 9              18.95              1.0       3.38         0.78
# 10              3.28              2.0       2.88         1.76
# 11             30.77              1.0       3.64         1.33
# 12              9.36              1.0       2.40         1.85
# 13             48.32              2.0       2.49         0.61
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import sklearn
#       2 print(sklearn.__version__)
#
# ModuleNotFoundError: No module named 'sklearn'
